# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys
from dotenv import load_dotenv
load_dotenv()

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2013-12-02 00:00:00+00:00   17.175095   19.686787   20.154642   19.672144
# 2013-12-03 00:00:00+00:00   17.645264   20.225714   20.227858   19.917143
# 2013-12-04 00:00:00+00:00   17.604149   20.178572   20.328215   20.029285
# 2013-12-05 00:00:00+00:00   17.694500   20.282143   20.540714   20.228930
# 2013-12-06 00:00:00+00:00   17.448980   20.000713   20.241072   19.984644
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00+00:00  193.223389  194.169998  196.270004  193.110001
# 2024-01-26 00:00:00+00:00  191.481934  192.419998  194.759995  191.940002
# 2024-01-29 00:00:00+00:00  190.795288  191.729996  192.199997  189.580002
# 2024-01-30 00:00:00+00:00  187.123276  188.039993  191.800003  187.470001
# 2024-01-31 00:00:00+00:00  183.501022  184.399994  187.100006  184.350006
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2013-12-02 00:00:00+00:00   19.928572  472544800
# 2013-12-03 00:00:00+00:00   19.939285  450968000
# 2013-12-04 00:00:00+00:00   20.196428  377809600
# 2013-12-05 00:00:00+00:00   20.451786  447580000
# 2013-12-06 00:00:00+00:00   20.206785  344352400
# ...                               ...        ...
# 2024-01-25 00:00:00+00:00  195.220001   54822100
# 2024-01-26 00:00:00+00:00  194.270004   44594000
# 2024-01-29 00:00:00+00:00  192.009995   47145600
# 2024-01-30 00:00:00+00:00  190.940002   55859400
# 2024-01-31 00:00:00+00:00  187.039993   55467800
#
# [2558 rows x 6 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)
print(tickers)
# Out:
#     ticker              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota       20883
# 1                     Building Products     Milwaukee, Wisconsin       42942
# 2                 Health Care Equipment  North Chicago, Illinois       20883
# 3                         Biotechnology  North Chicago, Illinois       41274
# 4        IT Consulting & Other Services          Dublin, Ireland       40730
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky       35709
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois       43822
# 500               Health Care Equipment          Warsaw, Indiana       37110
# 501                      Regional Banks     Salt Lake City, Utah       37064
# 502                     Pharmaceuticals   Parsippany, New Jersey       41446
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
# print(idx_tech)
tech_sector = tickers[idx_tech]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()
print(tech_tickers)
# Out:
# ['ACN', 'ADBE', 'AMD', 'AKAM', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'AVGO', 'CDNS', 'CDW', 'CSCO', 'CTSH', 'GLW', 'ENPH', 'EPAM', 'FFIV', 'FICO', 'FSLR', 'FTNT', 'IT', 'GEN', 'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'JBL', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MCHP', 'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PANW', 'PTC', 'QRVO', 'QCOM', 'ROP', 'CRM', 'STX', 'NOW', 'SWKS', 'SNPS', 'TEL', 'TDY', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN', 'WDC', 'ZBRA']

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %%
tech_raw_dt
# Out:
# Price                       Adj Close                                      \
# Ticker                           AAPL         ACN        ADBE         ADI
# Date
# 2000-01-03 00:00:00+00:00    0.843076         NaN   16.274673   28.095680
# 2000-01-04 00:00:00+00:00    0.771997         NaN   14.909400   26.674353
# 2000-01-05 00:00:00+00:00    0.783293         NaN   15.204174   27.063751
# 2000-01-06 00:00:00+00:00    0.715509         NaN   15.328289   26.323877
# 2000-01-07 00:00:00+00:00    0.749401         NaN   16.072983   27.063751
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00+00:00  229.979996  352.589996  429.989990  219.160004
# 2025-01-21 00:00:00+00:00  222.639999  356.420013  436.359985  221.449997
# 2025-01-22 00:00:00+00:00  223.830002  359.109985  437.320007  224.080002
# 2025-01-23 00:00:00+00:00  223.660004  363.260010  437.279999  228.350006
# 2025-01-24 00:00:00+00:00  222.779999  362.410004  435.380005  217.369995
#
# Price                                                                      \
# Ticker                           ADSK        AKAM        AMAT         AMD
# Date
# 2000-01-03 00:00:00+00:00    8.052907  321.250000   23.138021   15.500000
# 2000-01-04 00:00:00+00:00    7.660815  300.000000   21.994835   14.625000
# 2000-01-05 00:00:00+00:00    7.178245  283.500000   21.171740   15.000000
# 2000-01-06 00:00:00+00:00    6.740915  236.125000   21.206041   16.000000
# 2000-01-07 00:00:00+00:00    7.540173  248.375000   21.388947   16.250000
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00+00:00  291.450012   91.010002  192.050003  121.459999
# 2025-01-21 00:00:00+00:00  296.910004   94.709999  192.869995  122.279999
# 2025-01-22 00:00:00+00:00  301.450012   95.110001  195.509995  123.750000
# 2025-01-23 00:00:00+00:00  301.079987   95.889999  190.699997  123.040001
# 2025-01-24 00:00:00+00:00  300.829987   97.699997  186.750000  122.839996
#
# Price                                              ...   Volume          \
# Ticker                           ANET        ANSS  ...     SWKS     TDY
# Date                                               ...
# 2000-01-03 00:00:00+00:00         NaN    2.765625  ...   512000  315400
# 2000-01-04 00:00:00+00:00         NaN    2.687500  ...   292600  444300
# 2000-01-05 00:00:00+00:00         NaN    2.703125  ...   411800  109100
# 2000-01-06 00:00:00+00:00         NaN    2.703125  ...   385400  120700
# 2000-01-07 00:00:00+00:00         NaN    2.703125  ...   536000  222100
# ...                               ...         ...  ...      ...     ...
# 2025-01-17 00:00:00+00:00  119.949997  349.929993  ...  2150600  264400
# 2025-01-21 00:00:00+00:00  121.500000  352.070007  ...  2389300  377400
# 2025-01-22 00:00:00+00:00  129.820007  356.630005  ...  2774100  668700
# 2025-01-23 00:00:00+00:00  129.119995  360.359985  ...  1777300  384700
# 2025-01-24 00:00:00+00:00  129.169998  357.369995  ...  1803300  333500
#
# Price                                                                     \
# Ticker                           TEL      TER     TRMB       TXN     TYL
# Date
# 2000-01-03 00:00:00+00:00        NaN  1353500  8025000  10815600  138300
# 2000-01-04 00:00:00+00:00        NaN  1611800  4963200   7952400  135100
# 2000-01-05 00:00:00+00:00        NaN  1855800  1930200  12142400  187200
# 2000-01-06 00:00:00+00:00        NaN   964700  2230800  11758400  107200
# 2000-01-07 00:00:00+00:00        NaN   809200  2166600  12938800   78900
# ...                              ...      ...      ...       ...     ...
# 2025-01-17 00:00:00+00:00  4102600.0  2253700  1010700   5407500  308000
# 2025-01-21 00:00:00+00:00  2568300.0  4083000  1341800   9621700  235400
# 2025-01-22 00:00:00+00:00  3162200.0  2262100  1098600   8222000  177300
# 2025-01-23 00:00:00+00:00  1417800.0  2214300  1210400  12694700  214000
# 2025-01-24 00:00:00+00:00  1017300.0  2254000   895300  15856600  155300
#
# Price
# Ticker                        VRSN      WDC     ZBRA
# Date
# 2000-01-03 00:00:00+00:00  2270100  2461900  1055700
# 2000-01-04 00:00:00+00:00  3002200  7660300   522450
# 2000-01-05 00:00:00+00:00  6886600  3944600   612225
# 2000-01-06 00:00:00+00:00  4003200  2468400   263925
# 2000-01-07 00:00:00+00:00  3803200  9783000   333900
# ...                            ...      ...      ...
# 2025-01-17 00:00:00+00:00   503300  7160500   270600
# 2025-01-21 00:00:00+00:00   781800  7045600   446000
# 2025-01-22 00:00:00+00:00   674500  9340500   497500
# 2025-01-23 00:00:00+00:00   630100  7059500   377100
# 2025-01-24 00:00:00+00:00   563300  6046500   258900
#
# [6304 rows x 384 columns]

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index().sort_values(['Ticker', 'Date'])
# Out:
# Price                       Date Ticker   Adj Close       Close        High  \
# 0      2000-01-03 00:00:00+00:00   AAPL    0.843076    0.999442    1.004464
# 64     2000-01-04 00:00:00+00:00   AAPL    0.771997    0.915179    0.987723
# 128    2000-01-05 00:00:00+00:00   AAPL    0.783293    0.928571    0.987165
# 192    2000-01-06 00:00:00+00:00   AAPL    0.715509    0.848214    0.955357
# 256    2000-01-07 00:00:00+00:00   AAPL    0.749401    0.888393    0.901786
# ...                          ...    ...         ...         ...         ...
# 403199 2025-01-17 00:00:00+00:00   ZBRA  405.709991  405.709991  407.290009
# 403263 2025-01-21 00:00:00+00:00   ZBRA  418.070007  418.070007  419.850006
# 403327 2025-01-22 00:00:00+00:00   ZBRA  420.570007  420.570007  427.760010
# 403391 2025-01-23 00:00:00+00:00   ZBRA  421.109985  421.109985  422.290009
# 403455 2025-01-24 00:00:00+00:00   ZBRA  414.609985  414.609985  420.079987
#
# Price          Low        Open       Volume
# 0         0.907924    0.936384  535796800.0
# 64        0.903460    0.966518  512377600.0
# 128       0.919643    0.926339  778321600.0
# 192       0.848214    0.947545  767972800.0
# 256       0.852679    0.861607  460734400.0
# ...            ...         ...          ...
# 403199  402.290009  406.040009     270600.0
# 403263  407.619995  407.619995     446000.0
# 403327  419.589996  425.239990     497500.0
# 403391  414.450012  417.619995     377100.0
# 403455  413.739990  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None
tech_dt.columns
# Out:
# Index(['Date', 'Ticker', 'Adj Close', 'Close', 'High', 'Low', 'Open',
#        'Volume'],
#       dtype='object')

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
print(f"Size of {temp} before saving tech_dt: {get_dir_size(temp)} bytes")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")
# Out:
# Size of ../../05_src/data/temp/ before saving tech_dt: 64412896 bytes

# %%
tech_dt.shape
# Out:
# (403456, 8)

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 7.022341966629028 seconds.
# Csv file size 47.817664 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\bax\miniconda3\envs\igor_dsi\lib\site-packages\dask\dataframe\_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 1.4543769359588623 seconds.
# Parquet file size 16.59524 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(6c10673), _other='Ticker', options={})

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
dd_shift
# Out:
# C:\Users\bax\AppData\Local\Temp\ipykernel_21424\2499207102.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...
# Dask Name: groupbyapply, 3 expressions
# Expr=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(6c10673), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x00000213C12E8670>, meta=<no_default>, args=(), kwargs={})

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(6c10673), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x00000213C12E8670>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date   Adj Close       Close        High  \
# Ticker
# AAPL   2000-01-03 00:00:00+00:00    0.843076    0.999442    1.004464
# AAPL   2000-01-04 00:00:00+00:00    0.771997    0.915179    0.987723
# AAPL   2000-01-05 00:00:00+00:00    0.783293    0.928571    0.987165
# AAPL   2000-01-06 00:00:00+00:00    0.715509    0.848214    0.955357
# AAPL   2000-01-07 00:00:00+00:00    0.749401    0.888393    0.901786
# ...                          ...         ...         ...         ...
# ZBRA   2025-01-17 00:00:00+00:00  405.709991  405.709991  407.290009
# ZBRA   2025-01-21 00:00:00+00:00  418.070007  418.070007  419.850006
# ZBRA   2025-01-22 00:00:00+00:00  420.570007  420.570007  427.760010
# ZBRA   2025-01-23 00:00:00+00:00  421.109985  421.109985  422.290009
# ZBRA   2025-01-24 00:00:00+00:00  414.609985  414.609985  420.079987
#
#                Low        Open       Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL      0.907924    0.936384  535796800.0  2000          NaN       NaN
# AAPL      0.903460    0.966518  512377600.0  2000     0.999442 -0.084310
# AAPL      0.919643    0.926339  778321600.0  2000     0.915179  0.014633
# AAPL      0.848214    0.947545  767972800.0  2000     0.928571 -0.086538
# AAPL      0.852679    0.861607  460734400.0  2000     0.848214  0.047369
# ...            ...         ...          ...   ...          ...       ...
# ZBRA    402.290009  406.040009     270600.0  2025   402.720001  0.007424
# ZBRA    407.619995  407.619995     446000.0  2025   405.709991  0.030465
# ZBRA    419.589996  425.239990     497500.0  2025   418.070007  0.005980
# ZBRA    414.450012  417.619995     377100.0  2025   420.570007  0.001284
# ZBRA    413.739990  419.059998     258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-01-29 18:11:55,081, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-01-29 18:11:55,083, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-01-29 18:11:55,097, data_manager.py, 57, INFO, Processing all tickers
# 2025-01-29 18:11:55,099, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-01-29 18:11:55,102, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-01-29
# [*********************100%***********************]  503 of 503 completed
#
# 7 Failed downloads:
# ['PXD', 'PEAK', 'FLT', 'MRO', 'BRK.B', 'WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-01-29)')
# 2025-01-29 18:13:25,273, data_manager.py, 80, INFO, Saving data by year
# 2025-01-29 18:13:25,638, data_manager.py, 83, INFO, Saving data for A
# 2025-01-29 18:13:26,854, data_manager.py, 83, INFO, Saving data for AAL
# 2025-01-29 18:13:28,233, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-01-29 18:13:29,617, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-01-29 18:13:30,727, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-01-29 18:13:31,863, data_manager.py, 83, INFO, Saving data for ABT
# 2025-01-29 18:13:32,931, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-01-29 18:13:34,152, data_manager.py, 83, INFO, Saving data for ACN
# 2025-01-29 18:13:35,518, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-01-29 18:13:36,788, data_manager.py, 83, INFO, Saving data for ADI
# 2025-01-29 18:13:38,198, data_manager.py, 83, INFO, Saving data for ADM
# 2025-01-29 18:13:39,282, data_manager.py, 83, INFO, Saving data for ADP
# 2025-01-29 18:13:40,352, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-01-29 18:13:41,870, data_manager.py, 83, INFO, Saving data for AEE
# 2025-01-29 18:13:43,026, data_manager.py, 83, INFO, Saving data for AEP
# 2025-01-29 18:13:44,240, data_manager.py, 83, INFO, Saving data for AES
# 2025-01-29 18:13:45,473, data_manager.py, 83, INFO, Saving data for AFL
# 2025-01-29 18:13:46,537, data_manager.py, 83, INFO, Saving data for AIG
# 2025-01-29 18:13:47,696, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-01-29 18:13:49,188, data_manager.py, 83, INFO, Saving data for AJG
# 2025-01-29 18:13:50,552, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-01-29 18:13:52,087, data_manager.py, 83, INFO, Saving data for ALB
# 2025-01-29 18:13:53,263, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-01-29 18:13:54,339, data_manager.py, 83, INFO, Saving data for ALL
# 2025-01-29 18:13:55,582, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-01-29 18:13:56,650, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-01-29 18:13:58,086, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-01-29 18:13:59,526, data_manager.py, 83, INFO, Saving data for AMD
# 2025-01-29 18:14:00,798, data_manager.py, 83, INFO, Saving data for AME
# 2025-01-29 18:14:01,871, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-01-29 18:14:03,021, data_manager.py, 83, INFO, Saving data for AMP
# 2025-01-29 18:14:04,179, data_manager.py, 83, INFO, Saving data for AMT
# 2025-01-29 18:14:05,268, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-01-29 18:14:06,549, data_manager.py, 83, INFO, Saving data for ANET
# 2025-01-29 18:14:07,824, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-01-29 18:14:09,215, data_manager.py, 83, INFO, Saving data for AON
# 2025-01-29 18:14:10,330, data_manager.py, 83, INFO, Saving data for AOS
# 2025-01-29 18:14:11,413, data_manager.py, 83, INFO, Saving data for APA
# 2025-01-29 18:14:12,454, data_manager.py, 83, INFO, Saving data for APD
# 2025-01-29 18:14:13,746, data_manager.py, 83, INFO, Saving data for APH
# 2025-01-29 18:14:15,117, data_manager.py, 83, INFO, Saving data for APTV
# 2025-01-29 18:14:16,182, data_manager.py, 83, INFO, Saving data for ARE
# 2025-01-29 18:14:17,419, data_manager.py, 83, INFO, Saving data for ATO
# 2025-01-29 18:14:18,549, data_manager.py, 83, INFO, Saving data for AVB
# 2025-01-29 18:14:19,598, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-01-29 18:14:21,042, data_manager.py, 83, INFO, Saving data for AVY
# 2025-01-29 18:14:22,098, data_manager.py, 83, INFO, Saving data for AWK
# 2025-01-29 18:14:23,181, data_manager.py, 83, INFO, Saving data for AXON
# 2025-01-29 18:14:24,377, data_manager.py, 83, INFO, Saving data for AXP
# 2025-01-29 18:14:25,497, data_manager.py, 83, INFO, Saving data for AZO
# 2025-01-29 18:14:26,558, data_manager.py, 83, INFO, Saving data for BA
# 2025-01-29 18:14:27,827, data_manager.py, 83, INFO, Saving data for BAC
# 2025-01-29 18:14:28,921, data_manager.py, 83, INFO, Saving data for BALL
# 2025-01-29 18:14:30,041, data_manager.py, 83, INFO, Saving data for BAX
# 2025-01-29 18:14:31,383, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-01-29 18:14:32,423, data_manager.py, 83, INFO, Saving data for BBY
# 2025-01-29 18:14:33,496, data_manager.py, 83, INFO, Saving data for BDX
# 2025-01-29 18:14:34,791, data_manager.py, 83, INFO, Saving data for BEN
# 2025-01-29 18:14:35,824, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-01-29 18:14:36,968, data_manager.py, 83, INFO, Saving data for BG
# 2025-01-29 18:14:38,145, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-01-29 18:14:39,233, data_manager.py, 83, INFO, Saving data for BIO
# 2025-01-29 18:14:40,403, data_manager.py, 83, INFO, Saving data for BK
# 2025-01-29 18:14:41,704, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-01-29 18:14:42,755, data_manager.py, 83, INFO, Saving data for BKR
# 2025-01-29 18:14:43,807, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-01-29 18:14:45,090, data_manager.py, 83, INFO, Saving data for BLK
# 2025-01-29 18:14:46,289, data_manager.py, 83, INFO, Saving data for BMY
# 2025-01-29 18:14:47,434, data_manager.py, 83, INFO, Saving data for BR
# 2025-01-29 18:14:48,617, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-01-29 18:14:49,805, data_manager.py, 83, INFO, Saving data for BRO
# 2025-01-29 18:14:50,958, data_manager.py, 83, INFO, Saving data for BSX
# 2025-01-29 18:14:52,410, data_manager.py, 83, INFO, Saving data for BWA
# 2025-01-29 18:14:53,517, data_manager.py, 83, INFO, Saving data for BX
# 2025-01-29 18:14:54,616, data_manager.py, 83, INFO, Saving data for BXP
# 2025-01-29 18:14:55,757, data_manager.py, 83, INFO, Saving data for C
# 2025-01-29 18:14:56,959, data_manager.py, 83, INFO, Saving data for CAG
# 2025-01-29 18:14:58,044, data_manager.py, 83, INFO, Saving data for CAH
# 2025-01-29 18:14:59,264, data_manager.py, 83, INFO, Saving data for CARR
# 2025-01-29 18:15:00,339, data_manager.py, 83, INFO, Saving data for CAT
# 2025-01-29 18:15:01,465, data_manager.py, 83, INFO, Saving data for CB
# 2025-01-29 18:15:02,732, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-01-29 18:15:03,848, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-01-29 18:15:04,922, data_manager.py, 83, INFO, Saving data for CCI
# 2025-01-29 18:15:06,135, data_manager.py, 83, INFO, Saving data for CCL
# 2025-01-29 18:15:07,440, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-01-29 18:15:08,964, data_manager.py, 83, INFO, Saving data for CDW
# 2025-01-29 18:15:10,490, data_manager.py, 83, INFO, Saving data for CE
# 2025-01-29 18:15:11,782, data_manager.py, 83, INFO, Saving data for CEG
# 2025-01-29 18:15:12,897, data_manager.py, 83, INFO, Saving data for CF
# 2025-01-29 18:15:14,493, data_manager.py, 83, INFO, Saving data for CFG
# 2025-01-29 18:15:15,650, data_manager.py, 83, INFO, Saving data for CHD
# 2025-01-29 18:15:16,790, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-01-29 18:15:17,938, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-01-29 18:15:18,963, data_manager.py, 83, INFO, Saving data for CI
# 2025-01-29 18:15:20,289, data_manager.py, 83, INFO, Saving data for CINF
# 2025-01-29 18:15:21,417, data_manager.py, 83, INFO, Saving data for CL
# 2025-01-29 18:15:22,551, data_manager.py, 83, INFO, Saving data for CLX
# 2025-01-29 18:15:23,661, data_manager.py, 83, INFO, Saving data for CMA
# 2025-01-29 18:15:24,948, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-01-29 18:15:25,987, data_manager.py, 83, INFO, Saving data for CME
# 2025-01-29 18:15:27,174, data_manager.py, 83, INFO, Saving data for CMG
# 2025-01-29 18:15:28,331, data_manager.py, 83, INFO, Saving data for CMI
# 2025-01-29 18:15:29,462, data_manager.py, 83, INFO, Saving data for CMS
# 2025-01-29 18:15:30,768, data_manager.py, 83, INFO, Saving data for CNC
# 2025-01-29 18:15:31,917, data_manager.py, 83, INFO, Saving data for CNP
# 2025-01-29 18:15:32,982, data_manager.py, 83, INFO, Saving data for COF
# 2025-01-29 18:15:34,149, data_manager.py, 83, INFO, Saving data for COO
# 2025-01-29 18:15:35,316, data_manager.py, 83, INFO, Saving data for COP
# 2025-01-29 18:15:36,493, data_manager.py, 83, INFO, Saving data for COR
# 2025-01-29 18:15:37,627, data_manager.py, 83, INFO, Saving data for COST
# 2025-01-29 18:15:38,871, data_manager.py, 83, INFO, Saving data for CPB
# 2025-01-29 18:15:39,915, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-01-29 18:15:41,049, data_manager.py, 83, INFO, Saving data for CPT
# 2025-01-29 18:15:42,240, data_manager.py, 83, INFO, Saving data for CRL
# 2025-01-29 18:15:43,312, data_manager.py, 83, INFO, Saving data for CRM
# 2025-01-29 18:15:44,579, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-01-29 18:15:45,953, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-01-29 18:15:46,974, data_manager.py, 83, INFO, Saving data for CSX
# 2025-01-29 18:15:48,102, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-01-29 18:15:49,312, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-01-29 18:15:50,398, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-01-29 18:15:51,460, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-01-29 18:15:52,942, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-01-29 18:15:53,992, data_manager.py, 83, INFO, Saving data for CVS
# 2025-01-29 18:15:55,085, data_manager.py, 83, INFO, Saving data for CVX
# 2025-01-29 18:15:56,270, data_manager.py, 83, INFO, Saving data for CZR
# 2025-01-29 18:15:57,355, data_manager.py, 83, INFO, Saving data for D
# 2025-01-29 18:15:58,439, data_manager.py, 83, INFO, Saving data for DAL
# 2025-01-29 18:15:59,689, data_manager.py, 83, INFO, Saving data for DAY
# 2025-01-29 18:16:00,737, data_manager.py, 83, INFO, Saving data for DD
# 2025-01-29 18:16:01,832, data_manager.py, 83, INFO, Saving data for DE
# 2025-01-29 18:16:03,032, data_manager.py, 83, INFO, Saving data for DFS
# 2025-01-29 18:16:04,184, data_manager.py, 83, INFO, Saving data for DG
# 2025-01-29 18:16:05,255, data_manager.py, 83, INFO, Saving data for DGX
# 2025-01-29 18:16:06,456, data_manager.py, 83, INFO, Saving data for DHI
# 2025-01-29 18:16:07,582, data_manager.py, 83, INFO, Saving data for DHR
# 2025-01-29 18:16:08,743, data_manager.py, 83, INFO, Saving data for DIS
# 2025-01-29 18:16:09,903, data_manager.py, 83, INFO, Saving data for DLR
# 2025-01-29 18:16:11,049, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-01-29 18:16:12,102, data_manager.py, 83, INFO, Saving data for DOV
# 2025-01-29 18:16:13,355, data_manager.py, 83, INFO, Saving data for DOW
# 2025-01-29 18:16:14,500, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-01-29 18:16:15,585, data_manager.py, 83, INFO, Saving data for DRI
# 2025-01-29 18:16:16,678, data_manager.py, 83, INFO, Saving data for DTE
# 2025-01-29 18:16:17,899, data_manager.py, 83, INFO, Saving data for DUK
# 2025-01-29 18:16:19,076, data_manager.py, 83, INFO, Saving data for DVA
# 2025-01-29 18:16:20,159, data_manager.py, 83, INFO, Saving data for DVN
# 2025-01-29 18:16:21,373, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-01-29 18:16:22,433, data_manager.py, 83, INFO, Saving data for EA
# 2025-01-29 18:16:23,496, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-01-29 18:16:24,834, data_manager.py, 83, INFO, Saving data for ECL
# 2025-01-29 18:16:25,908, data_manager.py, 83, INFO, Saving data for ED
# 2025-01-29 18:16:27,128, data_manager.py, 83, INFO, Saving data for EFX
# 2025-01-29 18:16:28,327, data_manager.py, 83, INFO, Saving data for EG
# 2025-01-29 18:16:29,399, data_manager.py, 83, INFO, Saving data for EIX
# 2025-01-29 18:16:30,548, data_manager.py, 83, INFO, Saving data for EL
# 2025-01-29 18:16:31,737, data_manager.py, 83, INFO, Saving data for ELV
# 2025-01-29 18:16:32,758, data_manager.py, 83, INFO, Saving data for EMN
# 2025-01-29 18:16:33,855, data_manager.py, 83, INFO, Saving data for EMR
# 2025-01-29 18:16:35,061, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-01-29 18:16:36,355, data_manager.py, 83, INFO, Saving data for EOG
# 2025-01-29 18:16:37,393, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-01-29 18:16:38,830, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-01-29 18:16:39,880, data_manager.py, 83, INFO, Saving data for EQR
# 2025-01-29 18:16:41,036, data_manager.py, 83, INFO, Saving data for EQT
# 2025-01-29 18:16:42,320, data_manager.py, 83, INFO, Saving data for ES
# 2025-01-29 18:16:43,349, data_manager.py, 83, INFO, Saving data for ESS
# 2025-01-29 18:16:44,438, data_manager.py, 83, INFO, Saving data for ETN
# 2025-01-29 18:16:45,911, data_manager.py, 83, INFO, Saving data for ETR
# 2025-01-29 18:16:46,993, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-01-29 18:16:48,063, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-01-29 18:16:49,392, data_manager.py, 83, INFO, Saving data for EW
# 2025-01-29 18:16:50,433, data_manager.py, 83, INFO, Saving data for EXC
# 2025-01-29 18:16:51,627, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-01-29 18:16:52,869, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-01-29 18:16:54,020, data_manager.py, 83, INFO, Saving data for EXR
# 2025-01-29 18:16:55,086, data_manager.py, 83, INFO, Saving data for F
# 2025-01-29 18:16:56,408, data_manager.py, 83, INFO, Saving data for FANG
# 2025-01-29 18:16:57,433, data_manager.py, 83, INFO, Saving data for FAST
# 2025-01-29 18:16:58,556, data_manager.py, 83, INFO, Saving data for FCX
# 2025-01-29 18:16:59,708, data_manager.py, 83, INFO, Saving data for FDS
# 2025-01-29 18:17:01,115, data_manager.py, 83, INFO, Saving data for FDX
# 2025-01-29 18:17:02,234, data_manager.py, 83, INFO, Saving data for FE
# 2025-01-29 18:17:03,453, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-01-29 18:17:04,737, data_manager.py, 83, INFO, Saving data for FI
# 2025-01-29 18:17:05,803, data_manager.py, 83, INFO, Saving data for FICO
# 2025-01-29 18:17:07,340, data_manager.py, 83, INFO, Saving data for FIS
# 2025-01-29 18:17:08,400, data_manager.py, 83, INFO, Saving data for FITB
# 2025-01-29 18:17:09,473, data_manager.py, 83, INFO, Saving data for FLT
# 2025-01-29 18:17:10,722, data_manager.py, 83, INFO, Saving data for FMC
# 2025-01-29 18:17:11,738, data_manager.py, 83, INFO, Saving data for FOX
# 2025-01-29 18:17:12,864, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-01-29 18:17:14,036, data_manager.py, 83, INFO, Saving data for FRT
# 2025-01-29 18:17:15,286, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-01-29 18:17:16,693, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-01-29 18:17:18,137, data_manager.py, 83, INFO, Saving data for FTV
# 2025-01-29 18:17:19,208, data_manager.py, 83, INFO, Saving data for GD
# 2025-01-29 18:17:20,268, data_manager.py, 83, INFO, Saving data for GE
# 2025-01-29 18:17:21,520, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-01-29 18:17:22,553, data_manager.py, 83, INFO, Saving data for GEN
# 2025-01-29 18:17:23,955, data_manager.py, 83, INFO, Saving data for GILD
# 2025-01-29 18:17:25,111, data_manager.py, 83, INFO, Saving data for GIS
# 2025-01-29 18:17:26,249, data_manager.py, 83, INFO, Saving data for GL
# 2025-01-29 18:17:27,310, data_manager.py, 83, INFO, Saving data for GLW
# 2025-01-29 18:17:28,787, data_manager.py, 83, INFO, Saving data for GM
# 2025-01-29 18:17:29,823, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-01-29 18:17:30,986, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-01-29 18:17:32,148, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-01-29 18:17:33,251, data_manager.py, 83, INFO, Saving data for GPC
# 2025-01-29 18:17:34,445, data_manager.py, 83, INFO, Saving data for GPN
# 2025-01-29 18:17:35,681, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-01-29 18:17:36,701, data_manager.py, 83, INFO, Saving data for GS
# 2025-01-29 18:17:37,824, data_manager.py, 83, INFO, Saving data for GWW
# 2025-01-29 18:17:39,211, data_manager.py, 83, INFO, Saving data for HAL
# 2025-01-29 18:17:40,313, data_manager.py, 83, INFO, Saving data for HAS
# 2025-01-29 18:17:41,415, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-01-29 18:17:42,701, data_manager.py, 83, INFO, Saving data for HCA
# 2025-01-29 18:17:43,727, data_manager.py, 83, INFO, Saving data for HD
# 2025-01-29 18:17:44,898, data_manager.py, 83, INFO, Saving data for HES
# 2025-01-29 18:17:46,150, data_manager.py, 83, INFO, Saving data for HIG
# 2025-01-29 18:17:47,220, data_manager.py, 83, INFO, Saving data for HII
# 2025-01-29 18:17:48,267, data_manager.py, 83, INFO, Saving data for HLT
# 2025-01-29 18:17:49,593, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-01-29 18:17:50,603, data_manager.py, 83, INFO, Saving data for HON
# 2025-01-29 18:17:51,692, data_manager.py, 83, INFO, Saving data for HPE
# 2025-01-29 18:17:53,121, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-01-29 18:17:54,410, data_manager.py, 83, INFO, Saving data for HRL
# 2025-01-29 18:17:55,556, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-01-29 18:17:56,742, data_manager.py, 83, INFO, Saving data for HST
# 2025-01-29 18:17:57,846, data_manager.py, 83, INFO, Saving data for HSY
# 2025-01-29 18:17:58,917, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-01-29 18:18:00,276, data_manager.py, 83, INFO, Saving data for HUM
# 2025-01-29 18:18:01,484, data_manager.py, 83, INFO, Saving data for HWM
# 2025-01-29 18:18:02,629, data_manager.py, 83, INFO, Saving data for IBM
# 2025-01-29 18:18:04,112, data_manager.py, 83, INFO, Saving data for ICE
# 2025-01-29 18:18:05,216, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-01-29 18:18:06,325, data_manager.py, 83, INFO, Saving data for IEX
# 2025-01-29 18:18:07,650, data_manager.py, 83, INFO, Saving data for IFF
# 2025-01-29 18:18:08,759, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-01-29 18:18:09,876, data_manager.py, 83, INFO, Saving data for INCY
# 2025-01-29 18:18:11,077, data_manager.py, 83, INFO, Saving data for INTC
# 2025-01-29 18:18:12,399, data_manager.py, 83, INFO, Saving data for INTU
# 2025-01-29 18:18:13,780, data_manager.py, 83, INFO, Saving data for INVH
# 2025-01-29 18:18:15,021, data_manager.py, 83, INFO, Saving data for IP
# 2025-01-29 18:18:16,045, data_manager.py, 83, INFO, Saving data for IPG
# 2025-01-29 18:18:17,237, data_manager.py, 83, INFO, Saving data for IQV
# 2025-01-29 18:18:18,389, data_manager.py, 83, INFO, Saving data for IR
# 2025-01-29 18:18:19,511, data_manager.py, 83, INFO, Saving data for IRM
# 2025-01-29 18:18:20,607, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-01-29 18:18:21,834, data_manager.py, 83, INFO, Saving data for IT
# 2025-01-29 18:18:23,121, data_manager.py, 83, INFO, Saving data for ITW
# 2025-01-29 18:18:24,215, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-01-29 18:18:25,511, data_manager.py, 83, INFO, Saving data for J
# 2025-01-29 18:18:26,536, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-01-29 18:18:27,582, data_manager.py, 83, INFO, Saving data for JBL
# 2025-01-29 18:18:28,985, data_manager.py, 83, INFO, Saving data for JCI
# 2025-01-29 18:18:30,235, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-01-29 18:18:31,358, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-01-29 18:18:32,558, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-01-29 18:18:33,856, data_manager.py, 83, INFO, Saving data for JPM
# 2025-01-29 18:18:35,077, data_manager.py, 83, INFO, Saving data for K
# 2025-01-29 18:18:36,238, data_manager.py, 83, INFO, Saving data for KDP
# 2025-01-29 18:18:37,367, data_manager.py, 83, INFO, Saving data for KEY
# 2025-01-29 18:18:38,531, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-01-29 18:18:39,885, data_manager.py, 83, INFO, Saving data for KHC
# 2025-01-29 18:18:40,923, data_manager.py, 83, INFO, Saving data for KIM
# 2025-01-29 18:18:42,227, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-01-29 18:18:43,565, data_manager.py, 83, INFO, Saving data for KMB
# 2025-01-29 18:18:44,662, data_manager.py, 83, INFO, Saving data for KMI
# 2025-01-29 18:18:45,826, data_manager.py, 83, INFO, Saving data for KMX
# 2025-01-29 18:18:47,069, data_manager.py, 83, INFO, Saving data for KO
# 2025-01-29 18:18:48,121, data_manager.py, 83, INFO, Saving data for KR
# 2025-01-29 18:18:49,357, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-01-29 18:18:50,451, data_manager.py, 83, INFO, Saving data for L
# 2025-01-29 18:18:51,531, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-01-29 18:18:52,783, data_manager.py, 83, INFO, Saving data for LEN
# 2025-01-29 18:18:53,923, data_manager.py, 83, INFO, Saving data for LH
# 2025-01-29 18:18:54,984, data_manager.py, 83, INFO, Saving data for LHX
# 2025-01-29 18:18:56,096, data_manager.py, 83, INFO, Saving data for LIN
# 2025-01-29 18:18:57,303, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-01-29 18:18:58,473, data_manager.py, 83, INFO, Saving data for LLY
# 2025-01-29 18:18:59,592, data_manager.py, 83, INFO, Saving data for LMT
# 2025-01-29 18:19:00,837, data_manager.py, 83, INFO, Saving data for LNT
# 2025-01-29 18:19:01,892, data_manager.py, 83, INFO, Saving data for LOW
# 2025-01-29 18:19:03,008, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-01-29 18:19:04,474, data_manager.py, 83, INFO, Saving data for LULU
# 2025-01-29 18:19:05,485, data_manager.py, 83, INFO, Saving data for LUV
# 2025-01-29 18:19:06,544, data_manager.py, 83, INFO, Saving data for LVS
# 2025-01-29 18:19:07,956, data_manager.py, 83, INFO, Saving data for LW
# 2025-01-29 18:19:09,107, data_manager.py, 83, INFO, Saving data for LYB
# 2025-01-29 18:19:10,304, data_manager.py, 83, INFO, Saving data for LYV
# 2025-01-29 18:19:11,511, data_manager.py, 83, INFO, Saving data for MA
# 2025-01-29 18:19:12,550, data_manager.py, 83, INFO, Saving data for MAA
# 2025-01-29 18:19:13,884, data_manager.py, 83, INFO, Saving data for MAR
# 2025-01-29 18:19:16,208, data_manager.py, 83, INFO, Saving data for MAS
# 2025-01-29 18:19:17,657, data_manager.py, 83, INFO, Saving data for MCD
# 2025-01-29 18:19:19,071, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-01-29 18:19:20,453, data_manager.py, 83, INFO, Saving data for MCK
# 2025-01-29 18:19:21,916, data_manager.py, 83, INFO, Saving data for MCO
# 2025-01-29 18:19:23,062, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-01-29 18:19:24,373, data_manager.py, 83, INFO, Saving data for MDT
# 2025-01-29 18:19:25,922, data_manager.py, 83, INFO, Saving data for MET
# 2025-01-29 18:19:27,381, data_manager.py, 83, INFO, Saving data for META
# 2025-01-29 18:19:28,912, data_manager.py, 83, INFO, Saving data for MGM
# 2025-01-29 18:19:30,328, data_manager.py, 83, INFO, Saving data for MHK
# 2025-01-29 18:19:31,476, data_manager.py, 83, INFO, Saving data for MKC
# 2025-01-29 18:19:32,801, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-01-29 18:19:33,965, data_manager.py, 83, INFO, Saving data for MLM
# 2025-01-29 18:19:35,458, data_manager.py, 83, INFO, Saving data for MMC
# 2025-01-29 18:19:36,842, data_manager.py, 83, INFO, Saving data for MMM
# 2025-01-29 18:19:38,212, data_manager.py, 83, INFO, Saving data for MNST
# 2025-01-29 18:19:39,533, data_manager.py, 83, INFO, Saving data for MO
# 2025-01-29 18:19:40,624, data_manager.py, 83, INFO, Saving data for MOH
# 2025-01-29 18:19:41,872, data_manager.py, 83, INFO, Saving data for MOS
# 2025-01-29 18:19:43,242, data_manager.py, 83, INFO, Saving data for MPC
# 2025-01-29 18:19:44,666, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-01-29 18:19:46,216, data_manager.py, 83, INFO, Saving data for MRK
# 2025-01-29 18:19:47,595, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-01-29 18:19:48,941, data_manager.py, 83, INFO, Saving data for MRO
# 2025-01-29 18:19:50,622, data_manager.py, 83, INFO, Saving data for MS
# 2025-01-29 18:19:52,091, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-01-29 18:19:53,308, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-01-29 18:19:54,789, data_manager.py, 83, INFO, Saving data for MSI
# 2025-01-29 18:19:56,149, data_manager.py, 83, INFO, Saving data for MTB
# 2025-01-29 18:19:57,338, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-01-29 18:19:58,457, data_manager.py, 83, INFO, Saving data for MTD
# 2025-01-29 18:19:59,783, data_manager.py, 83, INFO, Saving data for MU
# 2025-01-29 18:20:01,428, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-01-29 18:20:02,458, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-01-29 18:20:03,572, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-01-29 18:20:04,749, data_manager.py, 83, INFO, Saving data for NEE
# 2025-01-29 18:20:05,919, data_manager.py, 83, INFO, Saving data for NEM
# 2025-01-29 18:20:07,183, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-01-29 18:20:08,493, data_manager.py, 83, INFO, Saving data for NI
# 2025-01-29 18:20:09,565, data_manager.py, 83, INFO, Saving data for NKE
# 2025-01-29 18:20:10,882, data_manager.py, 83, INFO, Saving data for NOC
# 2025-01-29 18:20:12,505, data_manager.py, 83, INFO, Saving data for NOW
# 2025-01-29 18:20:14,072, data_manager.py, 83, INFO, Saving data for NRG
# 2025-01-29 18:20:15,850, data_manager.py, 83, INFO, Saving data for NSC
# 2025-01-29 18:20:17,274, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-01-29 18:20:18,767, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-01-29 18:20:20,115, data_manager.py, 83, INFO, Saving data for NUE
# 2025-01-29 18:20:21,224, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-01-29 18:20:22,749, data_manager.py, 83, INFO, Saving data for NVR
# 2025-01-29 18:20:24,277, data_manager.py, 83, INFO, Saving data for NWS
# 2025-01-29 18:20:25,503, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-01-29 18:20:26,916, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-01-29 18:20:28,310, data_manager.py, 83, INFO, Saving data for O
# 2025-01-29 18:20:29,752, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-01-29 18:20:30,994, data_manager.py, 83, INFO, Saving data for OKE
# 2025-01-29 18:20:32,358, data_manager.py, 83, INFO, Saving data for OMC
# 2025-01-29 18:20:33,939, data_manager.py, 83, INFO, Saving data for ON
# 2025-01-29 18:20:35,259, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-01-29 18:20:36,729, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-01-29 18:20:38,169, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-01-29 18:20:39,417, data_manager.py, 83, INFO, Saving data for OXY
# 2025-01-29 18:20:40,752, data_manager.py, 83, INFO, Saving data for PANW
# 2025-01-29 18:20:42,591, data_manager.py, 83, INFO, Saving data for PARA
# 2025-01-29 18:20:43,689, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-01-29 18:20:44,979, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-01-29 18:20:46,140, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-01-29 18:20:47,461, data_manager.py, 83, INFO, Saving data for PCG
# 2025-01-29 18:20:48,713, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-01-29 18:20:49,747, data_manager.py, 83, INFO, Saving data for PEG
# 2025-01-29 18:20:51,033, data_manager.py, 83, INFO, Saving data for PEP
# 2025-01-29 18:20:52,328, data_manager.py, 83, INFO, Saving data for PFE
# 2025-01-29 18:20:53,443, data_manager.py, 83, INFO, Saving data for PFG
# 2025-01-29 18:20:54,665, data_manager.py, 83, INFO, Saving data for PG
# 2025-01-29 18:20:55,927, data_manager.py, 83, INFO, Saving data for PGR
# 2025-01-29 18:20:57,075, data_manager.py, 83, INFO, Saving data for PH
# 2025-01-29 18:20:58,165, data_manager.py, 83, INFO, Saving data for PHM
# 2025-01-29 18:20:59,315, data_manager.py, 83, INFO, Saving data for PKG
# 2025-01-29 18:21:00,485, data_manager.py, 83, INFO, Saving data for PLD
# 2025-01-29 18:21:01,647, data_manager.py, 83, INFO, Saving data for PM
# 2025-01-29 18:21:03,061, data_manager.py, 83, INFO, Saving data for PNC
# 2025-01-29 18:21:04,396, data_manager.py, 83, INFO, Saving data for PNR
# 2025-01-29 18:21:05,815, data_manager.py, 83, INFO, Saving data for PNW
# 2025-01-29 18:21:07,567, data_manager.py, 83, INFO, Saving data for PODD
# 2025-01-29 18:21:09,210, data_manager.py, 83, INFO, Saving data for POOL
# 2025-01-29 18:21:10,594, data_manager.py, 83, INFO, Saving data for PPG
# 2025-01-29 18:21:11,690, data_manager.py, 83, INFO, Saving data for PPL
# 2025-01-29 18:21:12,827, data_manager.py, 83, INFO, Saving data for PRU
# 2025-01-29 18:21:14,148, data_manager.py, 83, INFO, Saving data for PSA
# 2025-01-29 18:21:15,305, data_manager.py, 83, INFO, Saving data for PSX
# 2025-01-29 18:21:16,655, data_manager.py, 83, INFO, Saving data for PTC
# 2025-01-29 18:21:17,877, data_manager.py, 83, INFO, Saving data for PWR
# 2025-01-29 18:21:19,351, data_manager.py, 83, INFO, Saving data for PXD
# 2025-01-29 18:21:20,476, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-01-29 18:21:21,605, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-01-29 18:21:22,960, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-01-29 18:21:24,375, data_manager.py, 83, INFO, Saving data for RCL
# 2025-01-29 18:21:25,438, data_manager.py, 83, INFO, Saving data for REG
# 2025-01-29 18:21:26,791, data_manager.py, 83, INFO, Saving data for REGN
# 2025-01-29 18:21:27,909, data_manager.py, 83, INFO, Saving data for RF
# 2025-01-29 18:21:29,002, data_manager.py, 83, INFO, Saving data for RHI
# 2025-01-29 18:21:30,327, data_manager.py, 83, INFO, Saving data for RJF
# 2025-01-29 18:21:31,825, data_manager.py, 83, INFO, Saving data for RL
# 2025-01-29 18:21:33,059, data_manager.py, 83, INFO, Saving data for RMD
# 2025-01-29 18:21:34,422, data_manager.py, 83, INFO, Saving data for ROK
# 2025-01-29 18:21:35,568, data_manager.py, 83, INFO, Saving data for ROL
# 2025-01-29 18:21:37,345, data_manager.py, 83, INFO, Saving data for ROP
# 2025-01-29 18:21:39,001, data_manager.py, 83, INFO, Saving data for ROST
# 2025-01-29 18:21:40,532, data_manager.py, 83, INFO, Saving data for RSG
# 2025-01-29 18:21:41,691, data_manager.py, 83, INFO, Saving data for RTX
# 2025-01-29 18:21:42,986, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-01-29 18:21:44,301, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-01-29 18:21:45,629, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-01-29 18:21:46,815, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-01-29 18:21:48,316, data_manager.py, 83, INFO, Saving data for SHW
# 2025-01-29 18:21:49,606, data_manager.py, 83, INFO, Saving data for SJM
# 2025-01-29 18:21:50,756, data_manager.py, 83, INFO, Saving data for SLB
# 2025-01-29 18:21:52,066, data_manager.py, 83, INFO, Saving data for SNA
# 2025-01-29 18:21:53,208, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-01-29 18:21:54,602, data_manager.py, 83, INFO, Saving data for SO
# 2025-01-29 18:21:55,759, data_manager.py, 83, INFO, Saving data for SPG
# 2025-01-29 18:21:56,853, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-01-29 18:21:58,213, data_manager.py, 83, INFO, Saving data for SRE
# 2025-01-29 18:21:59,565, data_manager.py, 83, INFO, Saving data for STE
# 2025-01-29 18:22:00,930, data_manager.py, 83, INFO, Saving data for STLD
# 2025-01-29 18:22:02,097, data_manager.py, 83, INFO, Saving data for STT
# 2025-01-29 18:22:03,272, data_manager.py, 83, INFO, Saving data for STX
# 2025-01-29 18:22:04,566, data_manager.py, 83, INFO, Saving data for STZ
# 2025-01-29 18:22:05,970, data_manager.py, 83, INFO, Saving data for SWK
# 2025-01-29 18:22:07,465, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-01-29 18:22:09,115, data_manager.py, 83, INFO, Saving data for SYF
# 2025-01-29 18:22:10,507, data_manager.py, 83, INFO, Saving data for SYK
# 2025-01-29 18:22:11,609, data_manager.py, 83, INFO, Saving data for SYY
# 2025-01-29 18:22:12,880, data_manager.py, 83, INFO, Saving data for T
# 2025-01-29 18:22:13,927, data_manager.py, 83, INFO, Saving data for TAP
# 2025-01-29 18:22:15,206, data_manager.py, 83, INFO, Saving data for TDG
# 2025-01-29 18:22:16,619, data_manager.py, 83, INFO, Saving data for TDY
# 2025-01-29 18:22:18,042, data_manager.py, 83, INFO, Saving data for TECH
# 2025-01-29 18:22:19,353, data_manager.py, 83, INFO, Saving data for TEL
# 2025-01-29 18:22:20,695, data_manager.py, 83, INFO, Saving data for TER
# 2025-01-29 18:22:21,950, data_manager.py, 83, INFO, Saving data for TFC
# 2025-01-29 18:22:23,187, data_manager.py, 83, INFO, Saving data for TFX
# 2025-01-29 18:22:24,581, data_manager.py, 83, INFO, Saving data for TGT
# 2025-01-29 18:22:25,668, data_manager.py, 83, INFO, Saving data for TJX
# 2025-01-29 18:22:27,022, data_manager.py, 83, INFO, Saving data for TMO
# 2025-01-29 18:22:28,107, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-01-29 18:22:29,208, data_manager.py, 83, INFO, Saving data for TPR
# 2025-01-29 18:22:30,447, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-01-29 18:22:31,833, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-01-29 18:22:32,972, data_manager.py, 83, INFO, Saving data for TROW
# 2025-01-29 18:22:34,361, data_manager.py, 83, INFO, Saving data for TRV
# 2025-01-29 18:22:35,378, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-01-29 18:22:36,462, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-01-29 18:22:37,782, data_manager.py, 83, INFO, Saving data for TSN
# 2025-01-29 18:22:38,888, data_manager.py, 83, INFO, Saving data for TT
# 2025-01-29 18:22:40,056, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-01-29 18:22:41,380, data_manager.py, 83, INFO, Saving data for TXN
# 2025-01-29 18:22:42,561, data_manager.py, 83, INFO, Saving data for TXT
# 2025-01-29 18:22:43,738, data_manager.py, 83, INFO, Saving data for TYL
# 2025-01-29 18:22:45,687, data_manager.py, 83, INFO, Saving data for UAL
# 2025-01-29 18:22:47,209, data_manager.py, 83, INFO, Saving data for UBER
# 2025-01-29 18:22:48,613, data_manager.py, 83, INFO, Saving data for UDR
# 2025-01-29 18:22:49,899, data_manager.py, 83, INFO, Saving data for UHS
# 2025-01-29 18:22:51,161, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-01-29 18:22:52,260, data_manager.py, 83, INFO, Saving data for UNH
# 2025-01-29 18:22:53,336, data_manager.py, 83, INFO, Saving data for UNP
# 2025-01-29 18:22:54,413, data_manager.py, 83, INFO, Saving data for UPS
# 2025-01-29 18:22:55,863, data_manager.py, 83, INFO, Saving data for URI
# 2025-01-29 18:22:57,001, data_manager.py, 83, INFO, Saving data for USB
# 2025-01-29 18:22:58,268, data_manager.py, 83, INFO, Saving data for V
# 2025-01-29 18:22:59,584, data_manager.py, 83, INFO, Saving data for VFC
# 2025-01-29 18:23:00,655, data_manager.py, 83, INFO, Saving data for VICI
# 2025-01-29 18:23:01,934, data_manager.py, 83, INFO, Saving data for VLO
# 2025-01-29 18:23:03,411, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-01-29 18:23:04,688, data_manager.py, 83, INFO, Saving data for VMC
# 2025-01-29 18:23:06,314, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-01-29 18:23:07,791, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-01-29 18:23:09,504, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-01-29 18:23:10,620, data_manager.py, 83, INFO, Saving data for VTR
# 2025-01-29 18:23:11,930, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-01-29 18:23:13,260, data_manager.py, 83, INFO, Saving data for VZ
# 2025-01-29 18:23:14,440, data_manager.py, 83, INFO, Saving data for WAB
# 2025-01-29 18:23:16,218, data_manager.py, 83, INFO, Saving data for WAT
# 2025-01-29 18:23:17,826, data_manager.py, 83, INFO, Saving data for WBA
# 2025-01-29 18:23:19,740, data_manager.py, 83, INFO, Saving data for WBD
# 2025-01-29 18:23:21,115, data_manager.py, 83, INFO, Saving data for WDC
# 2025-01-29 18:23:22,367, data_manager.py, 83, INFO, Saving data for WEC
# 2025-01-29 18:23:23,700, data_manager.py, 83, INFO, Saving data for WELL
# 2025-01-29 18:23:25,142, data_manager.py, 83, INFO, Saving data for WFC
# 2025-01-29 18:23:26,446, data_manager.py, 83, INFO, Saving data for WHR
# 2025-01-29 18:23:28,015, data_manager.py, 83, INFO, Saving data for WM
# 2025-01-29 18:23:29,465, data_manager.py, 83, INFO, Saving data for WMB
# 2025-01-29 18:23:30,591, data_manager.py, 83, INFO, Saving data for WMT
# 2025-01-29 18:23:31,850, data_manager.py, 83, INFO, Saving data for WRB
# 2025-01-29 18:23:33,095, data_manager.py, 83, INFO, Saving data for WRK
# 2025-01-29 18:23:34,354, data_manager.py, 83, INFO, Saving data for WST
# 2025-01-29 18:23:35,498, data_manager.py, 83, INFO, Saving data for WTW
# 2025-01-29 18:23:36,553, data_manager.py, 83, INFO, Saving data for WY
# 2025-01-29 18:23:37,698, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-01-29 18:23:39,018, data_manager.py, 83, INFO, Saving data for XEL
# 2025-01-29 18:23:40,142, data_manager.py, 83, INFO, Saving data for XOM
# 2025-01-29 18:23:41,229, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-01-29 18:23:42,426, data_manager.py, 83, INFO, Saving data for XYL
# 2025-01-29 18:23:43,514, data_manager.py, 83, INFO, Saving data for YUM
# 2025-01-29 18:23:44,796, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-01-29 18:23:46,014, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-01-29 18:23:47,114, data_manager.py, 83, INFO, Saving data for ZION
# 2025-01-29 18:23:48,352, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
